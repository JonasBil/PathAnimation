# %%
print("hallo")
import matplotlib.pyplot as plt
# Out:
# hallo

# %%
import osmnx as ox
import networkx as nx


ox.__version__
# Out:
# '2.0.0rc2'

# %%
plt.plot([1,2,3,4])

# %%
gent = ox.graph_from_address('Gent, Belgium', network_type='walk', dist=1000)
ox.plot_graph(gent)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %%
basic_stats = ox.basic_stats(Gent)
print(basic_stats['circuity_avg'])
# Out:
# 1.0802066619092783

# %%
G = ox.graph_from_place('Piedmont, CA, USA', network_type='drive')
route = nx.shortest_path(G, orig, dest)
fig, ax = ox.plot_graph_route(G, route, route_linewidth=6, node_size=0, bgcolor='k')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 G = ox.graph_from_place('Piedmont, CA, USA', network_type='drive')
# ----> 2 route = nx.shortest_path(G, orig, dest)
#       3 fig, ax = ox.plot_graph_route(G, route, route_linewidth=6, node_size=0, bgcolor='k')
#
# NameError: name 'orig' is not defined
